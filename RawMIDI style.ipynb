# %% [markdown]
# # Implementation notes
#
# ## Abstract
#
# The reason for this implementation was to try and perform the classification with discrete data straight from the MIDI files in order to avoid inaccuracies and complications introduced in the processing of the continuous, multi-dimensional features we extracted using **jAudio**.
#
# ## Chosen Features
#
# The features used in this algorithm are extracted directly from the MIDI files and were chosen for simplicity's sake. The chosen features are as follows:
#
# ### Key Signature
#
# The first key signature given in the MIDI file. Subsequent key signature changes are ignored for simplicity.
# Seems to be a strong predictor.
#
# ### Time Signature
#
# The first time signature given in the MIDI file. Subsequent time signature changes are ignored since they are fairly uncommon in our dataset.
#
# ### Mean Tempo
#
# An average of the tempo changes throughout the whole piece. This is measured in ticks. The mean tempo is then discretized by finding the mean $\mu$ and standard deviation $\sigma^2$ of the mean tempos across all data points and then turning them into discrete values according to the rule:
#
# $T_{class} = 0 \quad$ if $T_{value} < \mu - \sigma^2$, Low tempo.
#
# $T_{class} = 1 \quad$ if $\mu - \sigma^2 <= T_{value} <= \mu + \sigma^2$, Mid tempo.
#
# $T_{class} = 2 \quad$ if $T_{value} < \mu + \sigma^2$, High tempo.

# %%
# Initialization Cell
import os
import numpy as np
from random import randint
from scipy.stats import norm
from mido import MidiFile

# %% [markdown]
# # Data Extraction

# %%
def extractData():
    fileNames = []
    data = []
    for file in os.listdir(os.getcwd() + "/midiFiles"):
        if file.endswith(".mid"):
            fileNames.append(file)
    
    for file in fileNames:
        data.append(MidiFile("midiFiles/" + file))
    return data

# %% [markdown]
# ## Labels

# %%
def getComposer(mid):
    for track in mid.tracks:
        for msg in track:
            if msg.type == 'text':
                return msg.text

# %%
# getComposer(rawData[0])

# %% [markdown]
# ## Features

# %%
def getTimeSig(mid):
    """
    Take in a MIDI file and return a list of time signature changes
    """
    
    
    for track in mid.tracks:
        for msg in track:
            if(msg.type == 'time_signature'):
                return str(msg.numerator) + ',' + str(msg.denominator)
    
    raise(NotImplementedError)

# %%
def getKey(mid):
    """
    Take in a midi file and return the key
    """
    
    for track in mid.tracks:
        for msg in track:
            if(msg.type == 'key_signature'):
                return(msg.key)

# %%
def getAvgTempo(mid):
    """
    Take in a MIDI file and return the average tempo
    """
    temps = []
    for track in mid.tracks:
        for msg in track:
            if msg.type == 'set_tempo':
                temps.append(msg.tempo)
    return sum(temps) / len(temps)

# %%
# getTimeSig(rawData[0])

# %% [markdown]
# # Data Preparation

# %%
def prepareData(data, accepted_composers):
    y = []
    x_key = []
    x_sig = []
    x_tempo = []
    for song in data:
        c = getComposer(song)
        for rule in accepted_composers:
            if rule in c:
                y.append(rule)
                x_key.append(getKey(song))
                x_sig.append(getTimeSig(song))
                x_tempo.append(getAvgTempo(song))
    
    # Discretize tempo data into low, mid, high
    [mu, std] = norm.fit(x_tempo)
    l1 = mu - std
    l2 = mu + std
    
    for i in range(len(x_tempo)):
        if x_tempo[i] < l1:
            x_tempo[i] = 0 # low tempo
        elif x_tempo[i] > l2:
            x_tempo[i] = 2 # high tempo
        else:
            x_tempo[i] = 1 # mid tempo. about 65% of data should lie in this group
            
    
    return [[x_key, x_sig, x_tempo],y]

# %%
# prepareData(rawData, ['Mozart', 'Chopin'])

# %%
def splitData(data, labels, ratio):
    n = int(len(data[0])*ratio)
    d_train = []
    l_train = []
    kt = []
    st = []
    for i in range(n):
        x = randint(0, len(labels) - 1)
        kt.append(data[0].pop(x))
        st.append(data[1].pop(x))
        l_train.append(labels.pop(x))
    d_train = [kt, st]
    return [d_train, l_train, data, labels]

# %%
# dat = splitData(xVals, yVals, 0.5)

# %% [markdown]
# # Learning

# %%
# rawData = extractData()
# [xVals, yVals] = prepareData(rawData, problem_space)

# %%
def learnNaiveBayes(t_data, t_labels):
    """
    Take in training data and corresponing labels, return a NB model
    Inputs:
        t_data - a list of features, each feature being a list of values
        t_labels - the corresponding labels
    """
    composers = list(set(t_labels))
    comp_counts = []
    tables = []
    py = []
    for composer in composers:
        py.append(t_labels.count(composer) / len(t_labels))
        comp_counts.append(t_labels.count(composer))
        
    for i in range(len(t_data)):
        f_vals = list(set(t_data[i]))
        px_feat = [0]*len(f_vals)
        for j in range(len(f_vals)):
            px_feat[j] = t_data[i].count(f_vals[j]) / len(t_labels)
        pxy_feat = []
        for composer in composers:
            k = []
            for j in range(len(t_labels)):
                if t_labels[i] == composer:
                    k.append(t_data[i][j])
            pxy_feat.append(k)
        feat_table = [f_vals, px_feat]
    
        for j in range(len(composers)):
            k = []
            for m in range(len(f_vals)):
                k.append((pxy_feat[j].count(f_vals[m])) / comp_counts[i])
            feat_table.append(k)
        tables.append(feat_table)
        
    return [composers, comp_counts, py, tables]

# %%
# trained_model = learnNaiveBayes(xVals, yVals)

# %% [markdown]
# # Classification

# %%
def classifySongNB(model, xVal):
    composers = model[0]
    comp_counts = model[1]
    py = model[2]
    probs = [1]*len(composers)
    tables = model[3]
    
    for i in range(len(xVal)):
        tab = tables[i]
        if xVal[i] not in tab[0]:
            break
            px = 1/ sum(comp_counts)
        else:
            j = tab[0].index(xVal[i])
            px = tab[1][j] + 1/ sum(comp_counts)
        
        for m in range(len(composers)):
            pxy = tab[2 + m][j]
        probs[m] *= (pxy * py[m]) / px
    return(composers[probs.index(max(probs))])

# %%
# trained_model = learnNaiveBayes(xVals, yVals)
# classifySongNB(trained_model, [xVals[0][0], xVals[1][0]])

# %% [markdown]
# # Testing

# %%
def testNB(model, t_data, t_labels):
    good = 0
    bad = 0
    n = len(t_labels)
    for i in range(len(t_labels)):
        prediction = classifySongNB(model, [t_data[0][i], t_data[1][i]])
#         print('True: ', t_labels[i], ' ; Predicted: ', prediction)
#         print('')
        if prediction == t_labels[i]:
            good += 1
        else:
            bad += 1
    print('Good: ', good / n, ', Baad: ', bad / n)

# %%
problem_space = ['Mozart', 'Chopin'] # ['Mozart', 'Chopin', 'Schubert']
rawData = extractData()
[xVals, yVals] = prepareData(rawData, problem_space)

# %%
dat = splitData(xVals, yVals, 0.5)
trained_model = learnNaiveBayes(dat[0], yVals)
testNB(trained_model, dat[2], dat[3])
# Out:
# Good:  0.7352941176470589 , Baad:  0.2647058823529412

# %%
# run the test 10 times
# DANGER
problem_space = ['Mozart', 'Chopin']
for i in range(10):
    rawData = extractData()
    [xVals, yVals] = prepareData(rawData, problem_space)
    dat = splitData(xVals, yVals, 0.6)
    trained_model = learnNaiveBayes(dat[0], yVals)
    testNB(trained_model, dat[2], dat[3])
# Out:
# Good:  0.8214285714285714 , Baad:  0.17857142857142858
# Good:  0.7857142857142857 , Baad:  0.21428571428571427
# Good:  0.7142857142857143 , Baad:  0.2857142857142857
# Good:  0.7142857142857143 , Baad:  0.2857142857142857
# Good:  0.7857142857142857 , Baad:  0.21428571428571427
# Good:  0.6785714285714286 , Baad:  0.32142857142857145
# Good:  0.6785714285714286 , Baad:  0.32142857142857145
# Good:  0.5357142857142857 , Baad:  0.4642857142857143
# Good:  0.75 , Baad:  0.25
# Good:  0.7142857142857143 , Baad:  0.2857142857142857

# %%
# run the test 10 times
# DANGER
problem_space = ['Mozart', 'Chopin', 'Schubert']
for i in range(10):
    rawData = extractData()
    [xVals, yVals] = prepareData(rawData, problem_space)
    dat = splitData(xVals, yVals, 0.6)
    trained_model = learnNaiveBayes(dat[0], yVals)
    testNB(trained_model, dat[2], dat[3])
# Out:
# Good:  0.48717948717948717 , Baad:  0.5128205128205128
# Good:  0.41025641025641024 , Baad:  0.5897435897435898
# Good:  0.5897435897435898 , Baad:  0.41025641025641024
# Good:  0.4358974358974359 , Baad:  0.5641025641025641
# Good:  0.4358974358974359 , Baad:  0.5641025641025641
# Good:  0.5641025641025641 , Baad:  0.4358974358974359
# Good:  0.5384615384615384 , Baad:  0.46153846153846156
# Good:  0.46153846153846156 , Baad:  0.5384615384615384
# Good:  0.48717948717948717 , Baad:  0.5128205128205128
# Good:  0.48717948717948717 , Baad:  0.5128205128205128

# %%
# problem_space = ['Mozart', 'Chopin'] # ['Mozart', 'Chopin', 'Schubert']
# rawData = extractData()

# %%
def getFeat(mid):
    """
    Take in a MIDI file and return a list of time signature changes
    """
    
    
    for track in mid.tracks:
        for msg in track:
            print(msg)
#             if(msg.type == 'time_signature'):
#                 return str(msg.numerator) + ',' + str(msg.denominator)
    
    raise(NotImplementedError)

# %%
getFeat(rawData[0])
# Out:
# <meta message track_name name='Vier Impromptus Opus postb. 142 D 935' time=0>
# <meta message track_name name='Impromptu Nr. 2 As-Dur' time=0>
# <meta message copyright text='Copyright © 2007 von Bernd Krüger.' time=0>
# <meta message text text='Franz Schubert ' time=0>
# <meta message text text='Allegretto' time=0>
# <meta message text text='Erstellt am 15.8.2007\n' time=0>
# <meta message text text='Update am 20.3.2014\n' time=0>
# <meta message text text='Dauer: 6:24 Minuten\n' time=0>
# <meta message time_signature numerator=3 denominator=4 clocks_per_click=24 notated_32nd_notes_per_beat=8 time=0>
# <meta message key_signature key='Ab' time=0>
# <meta message set_tempo tempo=597015 time=0>
# <meta message marker text='Allegretto' time=0>
# <meta message set_tempo tempo=597015 time=948>
# <meta message set_tempo tempo=545455 time=972>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=600000 time=1932>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=547945 time=472>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=638298 time=480>
# <meta message set_tempo tempo=621762 time=960>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=597015 time=468>
# <meta message set_tempo tempo=545455 time=492>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=576923 time=1920>
# <meta message set_tempo tempo=574163 time=12>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=600000 time=840>
# <meta message set_tempo tempo=600000 time=120>
# <meta message set_tempo tempo=547945 time=472>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=579710 time=480>
# <meta message set_tempo tempo=606061 time=600>
# <meta message set_tempo tempo=693642 time=120>
# <meta message set_tempo tempo=628272 time=240>
# <meta message set_tempo tempo=603015 time=948>
# <meta message set_tempo tempo=600000 time=492>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=600000 time=1932>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=547945 time=472>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=638298 time=480>
# <meta message set_tempo tempo=615385 time=960>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=597015 time=468>
# <meta message set_tempo tempo=545455 time=492>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=576923 time=1920>
# <meta message set_tempo tempo=574163 time=12>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=600000 time=840>
# <meta message set_tempo tempo=600000 time=120>
# <meta message set_tempo tempo=547945 time=472>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=579710 time=480>
# <meta message set_tempo tempo=606061 time=600>
# <meta message set_tempo tempo=693642 time=120>
# <meta message set_tempo tempo=628272 time=240>
# <meta message set_tempo tempo=508475 time=1200>
# <meta message set_tempo tempo=550459 time=240>
# <meta message set_tempo tempo=533333 time=480>
# <meta message set_tempo tempo=502092 time=480>
# <meta message set_tempo tempo=552995 time=480>
# <meta message set_tempo tempo=547945 time=480>
# <meta message set_tempo tempo=524017 time=480>
# <meta message set_tempo tempo=521739 time=480>
# <meta message set_tempo tempo=542986 time=480>
# <meta message set_tempo tempo=563380 time=480>
# <meta message set_tempo tempo=524017 time=480>
# <meta message set_tempo tempo=597015 time=960>
# <meta message set_tempo tempo=547945 time=240>
# <meta message set_tempo tempo=517241 time=1440>
# <meta message set_tempo tempo=547945 time=240>
# <meta message set_tempo tempo=576923 time=1440>
# <meta message set_tempo tempo=600000 time=968>
# <meta message set_tempo tempo=545455 time=472>
# <meta message set_tempo tempo=530973 time=960>
# <meta message set_tempo tempo=538117 time=480>
# <meta message set_tempo tempo=571429 time=1920>
# <meta message set_tempo tempo=600000 time=480>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=750000 time=980>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=547945 time=72>
# <meta message set_tempo tempo=794702 time=40>
# <meta message set_tempo tempo=621762 time=360>
# <meta message set_tempo tempo=666667 time=480>
# <meta message set_tempo tempo=666667 time=488>
# <meta message set_tempo tempo=1212121 time=1920>
# <meta message set_tempo tempo=736196 time=472>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=566038 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=600000 time=480>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=600000 time=1932>
# <meta message set_tempo tempo=615385 time=480>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=547945 time=12>
# <meta message set_tempo tempo=550459 time=48>
# <meta message set_tempo tempo=552995 time=52>
# <meta message set_tempo tempo=555556 time=48>
# <meta message set_tempo tempo=558140 time=52>
# <meta message set_tempo tempo=560748 time=48>
# <meta message set_tempo tempo=563380 time=52>
# <meta message set_tempo tempo=566038 time=48>
# <meta message set_tempo tempo=568720 time=52>
# <meta message set_tempo tempo=571429 time=48>
# <meta message set_tempo tempo=574163 time=52>
# <meta message set_tempo tempo=576923 time=48>
# <meta message set_tempo tempo=579710 time=52>
# <meta message set_tempo tempo=582524 time=48>
# <meta message set_tempo tempo=585366 time=52>
# <meta message set_tempo tempo=588235 time=40>
# <meta message set_tempo tempo=591133 time=48>
# <meta message set_tempo tempo=594059 time=52>
# <meta message set_tempo tempo=597015 time=48>
# <meta message set_tempo tempo=600000 time=52>
# <meta message set_tempo tempo=603015 time=48>
# <meta message set_tempo tempo=606061 time=52>
# <meta message set_tempo tempo=609137 time=48>
# <meta message set_tempo tempo=612245 time=52>
# <meta message set_tempo tempo=615385 time=48>
# <meta message set_tempo tempo=618557 time=52>
# <meta message set_tempo tempo=621762 time=48>
# <meta message set_tempo tempo=600000 time=1112>
# <meta message set_tempo tempo=597015 time=468>
# <meta message set_tempo tempo=545455 time=492>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=576923 time=1920>
# <meta message set_tempo tempo=574163 time=12>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=547945 time=12>
# <meta message set_tempo tempo=550459 time=48>
# <meta message set_tempo tempo=552995 time=52>
# <meta message set_tempo tempo=555556 time=48>
# <meta message set_tempo tempo=558140 time=52>
# <meta message set_tempo tempo=560748 time=48>
# <meta message set_tempo tempo=563380 time=52>
# <meta message set_tempo tempo=566038 time=48>
# <meta message set_tempo tempo=568720 time=52>
# <meta message set_tempo tempo=571429 time=48>
# <meta message set_tempo tempo=574163 time=52>
# <meta message set_tempo tempo=576923 time=48>
# <meta message set_tempo tempo=579710 time=52>
# <meta message set_tempo tempo=582524 time=48>
# <meta message set_tempo tempo=585366 time=52>
# <meta message set_tempo tempo=588235 time=40>
# <meta message set_tempo tempo=591133 time=48>
# <meta message set_tempo tempo=594059 time=52>
# <meta message set_tempo tempo=597015 time=48>
# <meta message set_tempo tempo=600000 time=52>
# <meta message set_tempo tempo=603015 time=48>
# <meta message set_tempo tempo=606061 time=52>
# <meta message set_tempo tempo=609137 time=48>
# <meta message set_tempo tempo=612245 time=52>
# <meta message set_tempo tempo=615385 time=48>
# <meta message set_tempo tempo=618557 time=52>
# <meta message set_tempo tempo=621762 time=48>
# <meta message set_tempo tempo=625000 time=52>
# <meta message set_tempo tempo=504202 time=1300>
# <meta message set_tempo tempo=550459 time=240>
# <meta message set_tempo tempo=533333 time=480>
# <meta message set_tempo tempo=502092 time=480>
# <meta message set_tempo tempo=552995 time=480>
# <meta message set_tempo tempo=547945 time=480>
# <meta message set_tempo tempo=524017 time=480>
# <meta message set_tempo tempo=521739 time=480>
# <meta message set_tempo tempo=542986 time=480>
# <meta message set_tempo tempo=563380 time=480>
# <meta message set_tempo tempo=524017 time=480>
# <meta message set_tempo tempo=597015 time=960>
# <meta message set_tempo tempo=547945 time=240>
# <meta message set_tempo tempo=517241 time=1440>
# <meta message set_tempo tempo=547945 time=240>
# <meta message set_tempo tempo=576923 time=1440>
# <meta message set_tempo tempo=600000 time=968>
# <meta message set_tempo tempo=545455 time=472>
# <meta message set_tempo tempo=530973 time=960>
# <meta message set_tempo tempo=538117 time=480>
# <meta message set_tempo tempo=571429 time=1920>
# <meta message set_tempo tempo=600000 time=480>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=750000 time=980>
# <meta message set_tempo tempo=750000 time=472>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=547945 time=72>
# <meta message set_tempo tempo=794702 time=40>
# <meta message set_tempo tempo=621762 time=360>
# <meta message set_tempo tempo=666667 time=480>
# <meta message set_tempo tempo=1212121 time=2408>
# <meta message set_tempo tempo=736196 time=472>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=566038 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=600000 time=480>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=600000 time=1932>
# <meta message set_tempo tempo=615385 time=480>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=547945 time=12>
# <meta message set_tempo tempo=550459 time=48>
# <meta message set_tempo tempo=552995 time=52>
# <meta message set_tempo tempo=555556 time=48>
# <meta message set_tempo tempo=558140 time=52>
# <meta message set_tempo tempo=560748 time=48>
# <meta message set_tempo tempo=563380 time=52>
# <meta message set_tempo tempo=566038 time=48>
# <meta message set_tempo tempo=568720 time=52>
# <meta message set_tempo tempo=571429 time=48>
# <meta message set_tempo tempo=574163 time=52>
# <meta message set_tempo tempo=576923 time=48>
# <meta message set_tempo tempo=579710 time=52>
# <meta message set_tempo tempo=582524 time=48>
# <meta message set_tempo tempo=585366 time=52>
# <meta message set_tempo tempo=588235 time=40>
# <meta message set_tempo tempo=591133 time=48>
# <meta message set_tempo tempo=594059 time=52>
# <meta message set_tempo tempo=597015 time=48>
# <meta message set_tempo tempo=600000 time=52>
# <meta message set_tempo tempo=603015 time=48>
# <meta message set_tempo tempo=606061 time=52>
# <meta message set_tempo tempo=609137 time=48>
# <meta message set_tempo tempo=612245 time=52>
# <meta message set_tempo tempo=615385 time=48>
# <meta message set_tempo tempo=618557 time=52>
# <meta message set_tempo tempo=621762 time=48>
# <meta message set_tempo tempo=600000 time=1112>
# <meta message set_tempo tempo=597015 time=468>
# <meta message set_tempo tempo=545455 time=492>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=576923 time=1920>
# <meta message set_tempo tempo=574163 time=12>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=547945 time=12>
# <meta message set_tempo tempo=550459 time=48>
# <meta message set_tempo tempo=552995 time=52>
# <meta message set_tempo tempo=555556 time=48>
# <meta message set_tempo tempo=558140 time=52>
# <meta message set_tempo tempo=560748 time=48>
# <meta message set_tempo tempo=563380 time=52>
# <meta message set_tempo tempo=566038 time=48>
# <meta message set_tempo tempo=568720 time=52>
# <meta message set_tempo tempo=571429 time=48>
# <meta message set_tempo tempo=574163 time=52>
# <meta message set_tempo tempo=576923 time=48>
# <meta message set_tempo tempo=579710 time=52>
# <meta message set_tempo tempo=582524 time=48>
# <meta message set_tempo tempo=585366 time=52>
# <meta message set_tempo tempo=588235 time=40>
# <meta message set_tempo tempo=591133 time=48>
# <meta message set_tempo tempo=594059 time=52>
# <meta message set_tempo tempo=597015 time=48>
# <meta message set_tempo tempo=600000 time=52>
# <meta message set_tempo tempo=603015 time=48>
# <meta message set_tempo tempo=606061 time=52>
# <meta message set_tempo tempo=609137 time=48>
# <meta message set_tempo tempo=612245 time=52>
# <meta message set_tempo tempo=615385 time=48>
# <meta message set_tempo tempo=618557 time=52>
# <meta message set_tempo tempo=621762 time=48>
# <meta message set_tempo tempo=625000 time=52>
# <meta message set_tempo tempo=600000 time=1060>
# <meta message marker text='Trio' time=0>
# <meta message set_tempo tempo=480000 time=456>
# <meta message key_signature key='Db' time=24>
# <meta message set_tempo tempo=478088 time=136>
# <meta message set_tempo tempo=476190 time=160>
# <meta message set_tempo tempo=474308 time=107>
# <meta message set_tempo tempo=472441 time=160>
# <meta message set_tempo tempo=470588 time=160>
# <meta message set_tempo tempo=468750 time=107>
# <meta message set_tempo tempo=466926 time=160>
# <meta message set_tempo tempo=465116 time=106>
# <meta message set_tempo tempo=474308 time=104>
# <meta message set_tempo tempo=461538 time=240>
# <meta message set_tempo tempo=452830 time=1920>
# <meta message set_tempo tempo=456274 time=480>
# <meta message set_tempo tempo=456274 time=480>
# <meta message set_tempo tempo=480000 time=960>
# <meta message set_tempo tempo=459770 time=480>
# <meta message set_tempo tempo=451128 time=3360>
# <meta message set_tempo tempo=459770 time=1440>
# <meta message set_tempo tempo=465116 time=1920>
# <meta message set_tempo tempo=458015 time=480>
# <meta message set_tempo tempo=461538 time=1920>
# <meta message set_tempo tempo=466926 time=480>
# <meta message set_tempo tempo=481928 time=1440>
# <meta message set_tempo tempo=463320 time=480>
# <meta message set_tempo tempo=480000 time=2640>
# <meta message set_tempo tempo=463320 time=240>
# <meta message set_tempo tempo=458015 time=480>
# <meta message set_tempo tempo=476190 time=1920>
# <meta message set_tempo tempo=461538 time=480>
# <meta message set_tempo tempo=458015 time=3360>
# <meta message set_tempo tempo=458015 time=840>
# <meta message set_tempo tempo=456274 time=240>
# <meta message set_tempo tempo=458015 time=360>
# <meta message set_tempo tempo=463320 time=480>
# <meta message set_tempo tempo=456274 time=480>
# <meta message set_tempo tempo=461538 time=2880>
# <meta message set_tempo tempo=468750 time=1920>
# <meta message set_tempo tempo=459770 time=960>
# <meta message set_tempo tempo=452830 time=3360>
# <meta message set_tempo tempo=458015 time=1440>
# <meta message set_tempo tempo=480000 time=480>
# <meta message set_tempo tempo=461538 time=480>
# <meta message set_tempo tempo=476190 time=1200>
# <meta message set_tempo tempo=459770 time=240>
# <meta message set_tempo tempo=444444 time=1080>
# <meta message set_tempo tempo=463320 time=360>
# <meta message set_tempo tempo=461538 time=120>
# <meta message set_tempo tempo=456274 time=360>
# <meta message set_tempo tempo=454545 time=1440>
# <meta message key_signature key='C' time=960>
# <meta message set_tempo tempo=454545 time=1440>
# <meta message set_tempo tempo=478088 time=1200>
# <meta message set_tempo tempo=452830 time=240>
# <meta message set_tempo tempo=449438 time=360>
# <meta message set_tempo tempo=449438 time=120>
# <meta message set_tempo tempo=444444 time=120>
# <meta message set_tempo tempo=465116 time=600>
# <meta message set_tempo tempo=436364 time=240>
# <meta message set_tempo tempo=454545 time=1200>
# <meta message set_tempo tempo=439560 time=240>
# <meta message set_tempo tempo=439560 time=2812>
# <meta message set_tempo tempo=441176 time=160>
# <meta message set_tempo tempo=442804 time=160>
# <meta message set_tempo tempo=444444 time=160>
# <meta message set_tempo tempo=446097 time=160>
# <meta message set_tempo tempo=447761 time=160>
# <meta message set_tempo tempo=449438 time=160>
# <meta message set_tempo tempo=451128 time=160>
# <meta message set_tempo tempo=452830 time=160>
# <meta message set_tempo tempo=454545 time=160>
# <meta message set_tempo tempo=456274 time=160>
# <meta message set_tempo tempo=458015 time=160>
# <meta message set_tempo tempo=459770 time=160>
# <meta message set_tempo tempo=461538 time=160>
# <meta message set_tempo tempo=463320 time=160>
# <meta message set_tempo tempo=487805 time=108>
# <meta message set_tempo tempo=502092 time=120>
# <meta message set_tempo tempo=463320 time=480>
# <meta message set_tempo tempo=468750 time=1412>
# <meta message set_tempo tempo=466926 time=40>
# <meta message set_tempo tempo=465116 time=40>
# <meta message set_tempo tempo=463320 time=40>
# <meta message set_tempo tempo=461538 time=40>
# <meta message set_tempo tempo=459770 time=40>
# <meta message set_tempo tempo=458015 time=40>
# <meta message set_tempo tempo=456274 time=40>
# <meta message set_tempo tempo=454545 time=40>
# <meta message set_tempo tempo=452830 time=40>
# <meta message set_tempo tempo=451128 time=40>
# <meta message set_tempo tempo=449438 time=40>
# <meta message set_tempo tempo=452830 time=560>
# <meta message set_tempo tempo=454545 time=120>
# <meta message set_tempo tempo=456274 time=80>
# <meta message set_tempo tempo=458015 time=80>
# <meta message set_tempo tempo=459770 time=80>
# <meta message key_signature key='Db' time=108>
# <meta message set_tempo tempo=463320 time=0>
# <meta message set_tempo tempo=463320 time=120>
# <meta message set_tempo tempo=466926 time=1320>
# <meta message set_tempo tempo=472441 time=600>
# <meta message set_tempo tempo=481928 time=360>
# <meta message set_tempo tempo=500000 time=120>
# <meta message set_tempo tempo=551724 time=120>
# <meta message set_tempo tempo=463320 time=240>
# <meta message set_tempo tempo=446097 time=2520>
# <meta message set_tempo tempo=449438 time=120>
# <meta message set_tempo tempo=461538 time=240>
# <meta message set_tempo tempo=454545 time=960>
# <meta message set_tempo tempo=476190 time=1440>
# <meta message set_tempo tempo=459770 time=480>
# <meta message set_tempo tempo=468750 time=1080>
# <meta message set_tempo tempo=459770 time=240>
# <meta message set_tempo tempo=459770 time=120>
# <meta message set_tempo tempo=452830 time=1800>
# <meta message set_tempo tempo=452830 time=120>
# <meta message set_tempo tempo=459770 time=1920>
# <meta message set_tempo tempo=459770 time=480>
# <meta message set_tempo tempo=452830 time=480>
# <meta message set_tempo tempo=461538 time=2400>
# <meta message set_tempo tempo=463320 time=120>
# <meta message set_tempo tempo=470588 time=1320>
# <meta message set_tempo tempo=500000 time=960>
# <meta message set_tempo tempo=459770 time=480>
# <meta message set_tempo tempo=452830 time=3360>
# <meta message set_tempo tempo=458015 time=1440>
# <meta message set_tempo tempo=480000 time=480>
# <meta message set_tempo tempo=461538 time=480>
# <meta message set_tempo tempo=476190 time=1200>
# <meta message set_tempo tempo=459770 time=240>
# <meta message set_tempo tempo=444444 time=1080>
# <meta message set_tempo tempo=463320 time=360>
# <meta message set_tempo tempo=461538 time=120>
# <meta message set_tempo tempo=456274 time=360>
# <meta message set_tempo tempo=454545 time=1440>
# <meta message key_signature key='C' time=960>
# <meta message set_tempo tempo=454545 time=1440>
# <meta message set_tempo tempo=478088 time=1200>
# <meta message set_tempo tempo=452830 time=240>
# <meta message set_tempo tempo=449438 time=360>
# <meta message set_tempo tempo=449438 time=120>
# <meta message set_tempo tempo=444444 time=120>
# <meta message set_tempo tempo=465116 time=600>
# <meta message set_tempo tempo=436364 time=240>
# <meta message set_tempo tempo=454545 time=1200>
# <meta message set_tempo tempo=439560 time=240>
# <meta message set_tempo tempo=439560 time=2812>
# <meta message set_tempo tempo=441176 time=160>
# <meta message set_tempo tempo=442804 time=160>
# <meta message set_tempo tempo=444444 time=160>
# <meta message set_tempo tempo=446097 time=160>
# <meta message set_tempo tempo=447761 time=160>
# <meta message set_tempo tempo=449438 time=160>
# <meta message set_tempo tempo=451128 time=160>
# <meta message set_tempo tempo=452830 time=160>
# <meta message set_tempo tempo=454545 time=160>
# <meta message set_tempo tempo=456274 time=160>
# <meta message set_tempo tempo=458015 time=160>
# <meta message set_tempo tempo=459770 time=160>
# <meta message set_tempo tempo=461538 time=160>
# <meta message set_tempo tempo=463320 time=160>
# <meta message set_tempo tempo=487805 time=108>
# <meta message set_tempo tempo=502092 time=120>
# <meta message set_tempo tempo=463320 time=480>
# <meta message set_tempo tempo=468750 time=1412>
# <meta message set_tempo tempo=466926 time=40>
# <meta message set_tempo tempo=465116 time=40>
# <meta message set_tempo tempo=463320 time=40>
# <meta message set_tempo tempo=461538 time=40>
# <meta message set_tempo tempo=459770 time=40>
# <meta message set_tempo tempo=458015 time=40>
# <meta message set_tempo tempo=456274 time=40>
# <meta message set_tempo tempo=454545 time=40>
# <meta message set_tempo tempo=452830 time=40>
# <meta message set_tempo tempo=451128 time=40>
# <meta message set_tempo tempo=449438 time=40>
# <meta message set_tempo tempo=452830 time=560>
# <meta message set_tempo tempo=454545 time=120>
# <meta message set_tempo tempo=456274 time=80>
# <meta message set_tempo tempo=458015 time=80>
# <meta message set_tempo tempo=459770 time=80>
# <meta message key_signature key='Db' time=108>
# <meta message set_tempo tempo=463320 time=0>
# <meta message set_tempo tempo=463320 time=120>
# <meta message set_tempo tempo=466926 time=1320>
# <meta message set_tempo tempo=472441 time=600>
# <meta message set_tempo tempo=481928 time=360>
# <meta message set_tempo tempo=500000 time=120>
# <meta message set_tempo tempo=551724 time=120>
# <meta message set_tempo tempo=463320 time=240>
# <meta message set_tempo tempo=446097 time=2520>
# <meta message set_tempo tempo=449438 time=120>
# <meta message set_tempo tempo=461538 time=240>
# <meta message set_tempo tempo=454545 time=960>
# <meta message set_tempo tempo=476190 time=1440>
# <meta message set_tempo tempo=459770 time=480>
# <meta message set_tempo tempo=468750 time=1080>
# <meta message set_tempo tempo=459770 time=240>
# <meta message set_tempo tempo=459770 time=120>
# <meta message set_tempo tempo=452830 time=1800>
# <meta message set_tempo tempo=452830 time=120>
# <meta message set_tempo tempo=459770 time=1920>
# <meta message set_tempo tempo=459770 time=480>
# <meta message set_tempo tempo=452830 time=480>
# <meta message set_tempo tempo=461538 time=2400>
# <meta message set_tempo tempo=463320 time=120>
# <meta message set_tempo tempo=470588 time=1320>
# <meta message set_tempo tempo=500000 time=960>
# <meta message set_tempo tempo=461538 time=480>
# <meta message set_tempo tempo=497925 time=2400>
# <meta message set_tempo tempo=458015 time=480>
# <meta message set_tempo tempo=463320 time=1320>
# <meta message set_tempo tempo=481928 time=1080>
# <meta message set_tempo tempo=465116 time=480>
# <meta message set_tempo tempo=480000 time=1440>
# <meta message set_tempo tempo=500000 time=1559>
# <meta message set_tempo tempo=502092 time=40>
# <meta message set_tempo tempo=504202 time=40>
# <meta message set_tempo tempo=506329 time=40>
# <meta message set_tempo tempo=508475 time=40>
# <meta message set_tempo tempo=510638 time=40>
# <meta message set_tempo tempo=512821 time=40>
# <meta message set_tempo tempo=515021 time=40>
# <meta message set_tempo tempo=519481 time=40>
# <meta message set_tempo tempo=521739 time=40>
# <meta message set_tempo tempo=524017 time=40>
# <meta message set_tempo tempo=526316 time=40>
# <meta message set_tempo tempo=528634 time=40>
# <meta message set_tempo tempo=530973 time=40>
# <meta message set_tempo tempo=533333 time=40>
# <meta message set_tempo tempo=535714 time=40>
# <meta message set_tempo tempo=538117 time=40>
# <meta message set_tempo tempo=542986 time=40>
# <meta message set_tempo tempo=547945 time=149>
# <meta message set_tempo tempo=550459 time=40>
# <meta message set_tempo tempo=552995 time=32>
# <meta message set_tempo tempo=555556 time=28>
# <meta message set_tempo tempo=558140 time=32>
# <meta message set_tempo tempo=560748 time=28>
# <meta message set_tempo tempo=563380 time=40>
# <meta message set_tempo tempo=566038 time=32>
# <meta message set_tempo tempo=568720 time=28>
# <meta message set_tempo tempo=571429 time=32>
# <meta message set_tempo tempo=574163 time=28>
# <meta message set_tempo tempo=576923 time=32>
# <meta message set_tempo tempo=579710 time=40>
# <meta message set_tempo tempo=582524 time=28>
# <meta message set_tempo tempo=585366 time=32>
# <meta message set_tempo tempo=588235 time=28>
# <meta message set_tempo tempo=591133 time=32>
# <meta message set_tempo tempo=594059 time=40>
# <meta message set_tempo tempo=597015 time=28>
# <meta message set_tempo tempo=600000 time=32>
# <meta message set_tempo tempo=603015 time=28>
# <meta message set_tempo tempo=606061 time=32>
# <meta message set_tempo tempo=609137 time=28>
# <meta message set_tempo tempo=612245 time=40>
# <meta message set_tempo tempo=615385 time=32>
# <meta message set_tempo tempo=618557 time=28>
# <meta message set_tempo tempo=621762 time=32>
# <meta message set_tempo tempo=625000 time=28>
# <meta message set_tempo tempo=628272 time=32>
# <meta message set_tempo tempo=631579 time=40>
# <meta message set_tempo tempo=634921 time=28>
# <meta message set_tempo tempo=638298 time=32>
# <meta message set_tempo tempo=641711 time=28>
# <meta message set_tempo tempo=645161 time=32>
# <meta message set_tempo tempo=648649 time=40>
# <meta message set_tempo tempo=652174 time=28>
# <meta message set_tempo tempo=655738 time=32>
# <meta message set_tempo tempo=659341 time=28>
# <meta message set_tempo tempo=662983 time=32>
# <meta message set_tempo tempo=666667 time=28>
# <meta message set_tempo tempo=670391 time=40>
# <meta message set_tempo tempo=674157 time=32>
# <meta message set_tempo tempo=677966 time=28>
# <meta message set_tempo tempo=681818 time=32>
# <meta message set_tempo tempo=685714 time=28>
# <meta message set_tempo tempo=689655 time=32>
# <meta message set_tempo tempo=603015 time=20>
# <meta message key_signature key='Ab' time=480>
# <meta message set_tempo tempo=600000 time=0>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=600000 time=1932>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=547945 time=472>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=638298 time=480>
# <meta message set_tempo tempo=615385 time=960>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=597015 time=468>
# <meta message set_tempo tempo=545455 time=492>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=576923 time=1920>
# <meta message set_tempo tempo=574163 time=12>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=600000 time=840>
# <meta message set_tempo tempo=600000 time=120>
# <meta message set_tempo tempo=547945 time=472>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=579710 time=480>
# <meta message set_tempo tempo=606061 time=600>
# <meta message set_tempo tempo=693642 time=120>
# <meta message set_tempo tempo=628272 time=240>
# <meta message set_tempo tempo=500000 time=1200>
# <meta message set_tempo tempo=550459 time=240>
# <meta message set_tempo tempo=533333 time=480>
# <meta message set_tempo tempo=502092 time=480>
# <meta message set_tempo tempo=552995 time=480>
# <meta message set_tempo tempo=547945 time=480>
# <meta message set_tempo tempo=524017 time=480>
# <meta message set_tempo tempo=521739 time=480>
# <meta message set_tempo tempo=542986 time=480>
# <meta message set_tempo tempo=563380 time=480>
# <meta message set_tempo tempo=524017 time=480>
# <meta message set_tempo tempo=597015 time=960>
# <meta message set_tempo tempo=547945 time=240>
# <meta message set_tempo tempo=517241 time=1440>
# <meta message set_tempo tempo=547945 time=240>
# <meta message set_tempo tempo=576923 time=1440>
# <meta message set_tempo tempo=600000 time=968>
# <meta message set_tempo tempo=545455 time=472>
# <meta message set_tempo tempo=530973 time=960>
# <meta message set_tempo tempo=538117 time=480>
# <meta message set_tempo tempo=571429 time=1920>
# <meta message set_tempo tempo=600000 time=480>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=750000 time=980>
# <meta message set_tempo tempo=750000 time=472>
# <meta message set_tempo tempo=545455 time=8>
# <meta message set_tempo tempo=547945 time=72>
# <meta message set_tempo tempo=794702 time=40>
# <meta message set_tempo tempo=621762 time=360>
# <meta message set_tempo tempo=666667 time=480>
# <meta message set_tempo tempo=710059 time=1920>
# <meta message set_tempo tempo=1212121 time=488>
# <meta message set_tempo tempo=736196 time=472>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=566038 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=600000 time=480>
# <meta message set_tempo tempo=545455 time=468>
# <meta message set_tempo tempo=600000 time=1932>
# <meta message set_tempo tempo=615385 time=480>
# <meta message set_tempo tempo=600000 time=960>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=547945 time=12>
# <meta message set_tempo tempo=550459 time=48>
# <meta message set_tempo tempo=552995 time=52>
# <meta message set_tempo tempo=555556 time=48>
# <meta message set_tempo tempo=558140 time=52>
# <meta message set_tempo tempo=560748 time=48>
# <meta message set_tempo tempo=563380 time=52>
# <meta message set_tempo tempo=566038 time=48>
# <meta message set_tempo tempo=568720 time=52>
# <meta message set_tempo tempo=571429 time=48>
# <meta message set_tempo tempo=574163 time=52>
# <meta message set_tempo tempo=576923 time=48>
# <meta message set_tempo tempo=579710 time=52>
# <meta message set_tempo tempo=582524 time=48>
# <meta message set_tempo tempo=585366 time=52>
# <meta message set_tempo tempo=588235 time=40>
# <meta message set_tempo tempo=591133 time=48>
# <meta message set_tempo tempo=594059 time=52>
# <meta message set_tempo tempo=597015 time=48>
# <meta message set_tempo tempo=600000 time=52>
# <meta message set_tempo tempo=603015 time=48>
# <meta message set_tempo tempo=606061 time=52>
# <meta message set_tempo tempo=609137 time=48>
# <meta message set_tempo tempo=612245 time=52>
# <meta message set_tempo tempo=615385 time=48>
# <meta message set_tempo tempo=618557 time=52>
# <meta message set_tempo tempo=621762 time=48>
# <meta message set_tempo tempo=600000 time=1112>
# <meta message set_tempo tempo=597015 time=468>
# <meta message set_tempo tempo=545455 time=492>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=576923 time=1920>
# <meta message set_tempo tempo=574163 time=12>
# <meta message set_tempo tempo=550459 time=488>
# <meta message set_tempo tempo=600000 time=952>
# <meta message set_tempo tempo=597015 time=480>
# <meta message set_tempo tempo=545455 time=480>
# <meta message set_tempo tempo=571429 time=968>
# <meta message set_tempo tempo=545455 time=460>
# <meta message set_tempo tempo=547945 time=960>
# <meta message set_tempo tempo=547945 time=12>
# <meta message set_tempo tempo=550459 time=48>
# <meta message set_tempo tempo=552995 time=52>
# <meta message set_tempo tempo=555556 time=48>
# <meta message set_tempo tempo=558140 time=52>
# <meta message set_tempo tempo=560748 time=48>
# <meta message set_tempo tempo=563380 time=52>
# <meta message set_tempo tempo=566038 time=48>
# <meta message set_tempo tempo=568720 time=52>
# <meta message set_tempo tempo=571429 time=48>
# <meta message set_tempo tempo=574163 time=52>
# <meta message set_tempo tempo=576923 time=48>
# <meta message set_tempo tempo=579710 time=52>
# <meta message set_tempo tempo=582524 time=48>
# <meta message set_tempo tempo=585366 time=52>
# <meta message set_tempo tempo=588235 time=40>
# <meta message set_tempo tempo=591133 time=48>
# <meta message set_tempo tempo=594059 time=52>
# <meta message set_tempo tempo=597015 time=48>
# <meta message set_tempo tempo=600000 time=52>
# <meta message set_tempo tempo=603015 time=48>
# <meta message set_tempo tempo=606061 time=52>
# <meta message set_tempo tempo=609137 time=48>
# <meta message set_tempo tempo=612245 time=52>
# <meta message set_tempo tempo=615385 time=48>
# <meta message set_tempo tempo=618557 time=52>
# <meta message set_tempo tempo=621762 time=48>
# <meta message set_tempo tempo=625000 time=52>
# <meta message set_tempo tempo=648649 time=3468>
# <meta message set_tempo tempo=600000 time=460>
# <meta message set_tempo tempo=600000 time=492>
# <meta message set_tempo tempo=600000 time=8>
# <meta message set_tempo tempo=603015 time=20>
# <meta message set_tempo tempo=606061 time=20>
# <meta message set_tempo tempo=609137 time=20>
# <meta message set_tempo tempo=612245 time=20>
# <meta message set_tempo tempo=615385 time=12>
# <meta message set_tempo tempo=618557 time=20>
# <meta message set_tempo tempo=621762 time=20>
# <meta message set_tempo tempo=625000 time=20>
# <meta message set_tempo tempo=628272 time=20>
# <meta message set_tempo tempo=631579 time=8>
# <meta message set_tempo tempo=634921 time=20>
# <meta message set_tempo tempo=638298 time=20>
# <meta message set_tempo tempo=641711 time=20>
# <meta message set_tempo tempo=645161 time=20>
# <meta message set_tempo tempo=648649 time=12>
# <meta message set_tempo tempo=652174 time=20>
# <meta message set_tempo tempo=655738 time=20>
# <meta message set_tempo tempo=659341 time=20>
# <meta message set_tempo tempo=662983 time=20>
# <meta message set_tempo tempo=666667 time=8>
# <meta message set_tempo tempo=670391 time=20>
# <meta message set_tempo tempo=674157 time=20>
# <meta message set_tempo tempo=677966 time=20>
# <meta message set_tempo tempo=681818 time=20>
# <meta message set_tempo tempo=685714 time=12>
# <meta message set_tempo tempo=689655 time=20>
# <meta message set_tempo tempo=693642 time=20>
# <meta message set_tempo tempo=697674 time=20>
# <meta message set_tempo tempo=701754 time=20>
# <meta message set_tempo tempo=705882 time=8>
# <meta message set_tempo tempo=710059 time=20>
# <meta message set_tempo tempo=714286 time=20>
# <meta message set_tempo tempo=718563 time=20>
# <meta message set_tempo tempo=722892 time=20>
# <meta message set_tempo tempo=727273 time=12>
# <meta message set_tempo tempo=731707 time=20>
# <meta message set_tempo tempo=736196 time=20>
# <meta message set_tempo tempo=740741 time=20>
# <meta message set_tempo tempo=745342 time=20>
# <meta message set_tempo tempo=750000 time=8>
# <meta message set_tempo tempo=754717 time=20>
# <meta message set_tempo tempo=759494 time=20>
# <meta message set_tempo tempo=764331 time=20>
# <meta message set_tempo tempo=769231 time=20>
# <meta message set_tempo tempo=774194 time=12>
# <meta message set_tempo tempo=779221 time=20>
# <meta message set_tempo tempo=784314 time=20>
# <meta message set_tempo tempo=789474 time=20>
# <meta message set_tempo tempo=794702 time=20>
# <meta message set_tempo tempo=800000 time=8>
# <meta message set_tempo tempo=805369 time=20>
# <meta message set_tempo tempo=810811 time=20>
# <meta message set_tempo tempo=816327 time=20>
# <meta message set_tempo tempo=821918 time=20>
# <meta message set_tempo tempo=827586 time=12>
# <meta message set_tempo tempo=833333 time=20>
# <meta message set_tempo tempo=839161 time=20>
# <meta message set_tempo tempo=845070 time=20>
# <meta message set_tempo tempo=851064 time=20>
# <meta message set_tempo tempo=857143 time=8>
# <meta message set_tempo tempo=863309 time=20>
# <meta message set_tempo tempo=869565 time=20>
# <meta message set_tempo tempo=875912 time=20>
# <meta message set_tempo tempo=882353 time=20>
# <meta message set_tempo tempo=888889 time=12>
# <meta message set_tempo tempo=895522 time=20>
# <meta message set_tempo tempo=902256 time=20>
# <meta message set_tempo tempo=909091 time=20>
# <meta message set_tempo tempo=916031 time=20>
# <meta message set_tempo tempo=923077 time=8>
# <meta message set_tempo tempo=930233 time=20>
# <meta message set_tempo tempo=937500 time=20>
# <meta message set_tempo tempo=944882 time=20>
# <meta message set_tempo tempo=952381 time=20>
# <meta message set_tempo tempo=960000 time=12>
# <meta message set_tempo tempo=967742 time=20>
# <meta message set_tempo tempo=975610 time=20>
# <meta message set_tempo tempo=983607 time=20>
# <meta message set_tempo tempo=991736 time=8>
# <meta message set_tempo tempo=736196 time=12>
# <meta message end_of_track time=0>
# <meta message track_name name='Right ' time=0>
# program_change channel=0 program=0 time=0
# control_change channel=0 control=7 value=80 time=0
# control_change channel=0 control=91 value=124 time=0
# note_on channel=0 note=63 velocity=46 time=960
# note_on channel=0 note=63 velocity=0 time=475
# note_on channel=0 note=68 velocity=46 time=5
# note_on channel=0 note=60 velocity=34 time=0
# note_on channel=0 note=63 velocity=34 time=0
# note_on channel=0 note=63 velocity=0 time=475
# note_on channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=68 velocity=0 time=0
# note_on channel=0 note=68 velocity=46 time=5
# note_on channel=0 note=60 velocity=34 time=0
# note_on channel=0 note=63 velocity=34 time=0
# note_on channel=0 note=68 velocity=0 time=720
# note_on channel=0 note=70 velocity=39 time=0
# note_on channel=0 note=70 velocity=0 time=240
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=61 velocity=34 time=0
# note_on channel=0 note=63 velocity=34 time=0
# note_on channel=0 note=68 velocity=46 time=0
# note_on channel=0 note=68 velocity=0 time=475
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=61 velocity=0 time=0
# note_on channel=0 note=61 velocity=34 time=5
# note_on channel=0 note=67 velocity=46 time=0
# note_on channel=0 note=63 velocity=34 time=0
# note_on channel=0 note=67 velocity=0 time=720
# note_on channel=0 note=70 velocity=37 time=0
# note_on channel=0 note=70 velocity=0 time=238
# note_on channel=0 note=63 velocity=0 time=2
# note_on channel=0 note=61 velocity=0 time=0
# note_on channel=0 note=70 velocity=46 time=0
# note_on channel=0 note=70 velocity=0 time=475
# note_on channel=0 note=63 velocity=38 time=5
# note_on channel=0 note=68 velocity=51 time=0
# note_on channel=0 note=68 velocity=0 time=475
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=63 velocity=39 time=5
# note_on channel=0 note=61 velocity=39 time=0
# note_on channel=0 note=70 velocity=52 time=0
# note_on channel=0 note=70 velocity=0 time=475
# note_on channel=0 note=61 velocity=0 time=0
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=63 velocity=40 time=5
# note_on channel=0 note=60 velocity=40 time=0
# note_on channel=0 note=72 velocity=55 time=0
# note_on channel=0 note=72 velocity=0 time=960
# note_on channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=63 velocity=55 time=0
# note_on channel=0 note=63 velocity=0 time=475
# note_on channel=0 note=72 velocity=66 time=5
# note_on channel=0 note=60 velocity=49 time=0
# note_on channel=0 note=63 velocity=49 time=0
# note_on channel=0 note=63 velocity=0 time=475
# note_on channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=63 velocity=50 time=5
# note_on channel=0 note=60 velocity=50 time=0
# note_on channel=0 note=72 velocity=67 time=0
# note_on channel=0 note=72 velocity=0 time=720
# note_on channel=0 note=60 velocity=0 time=0
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=61 velocity=42 time=0
# note_on channel=0 note=73 velocity=57 time=0
# note_on channel=0 note=63 velocity=42 time=0
# note_on channel=0 note=63 velocity=0 time=240
# note_on channel=0 note=73 velocity=0 time=0
# note_on channel=0 note=61 velocity=0 time=0
# note_on channel=0 note=63 velocity=48 time=0
# note_on channel=0 note=72 velocity=65 time=0
# note_on channel=0 note=60 velocity=48 time=0
# note_on channel=0 note=60 velocity=0 time=475
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=58 velocity=43 time=5
# note_on channel=0 note=63 velocity=43 time=0
# note_on channel=0 note=70 velocity=58 time=0
# note_on channel=0 note=70 velocity=0 time=720
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=58 velocity=0 time=0
# note_on channel=0 note=72 velocity=52 time=0
# note_on channel=0 note=63 velocity=39 time=0
# note_on channel=0 note=60 velocity=39 time=0
# note_on channel=0 note=60 velocity=0 time=240
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=58 velocity=41 time=0
# note_on channel=0 note=63 velocity=41 time=0
# note_on channel=0 note=70 velocity=56 time=0
# note_on channel=0 note=70 velocity=0 time=475
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=58 velocity=0 time=0
# note_on channel=0 note=63 velocity=39 time=5
# note_on channel=0 note=68 velocity=52 time=0
# note_on channel=0 note=56 velocity=39 time=0
# note_on channel=0 note=56 velocity=0 time=475
# note_on channel=0 note=68 velocity=0 time=0
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=75 velocity=66 time=5
# note_on channel=0 note=63 velocity=49 time=0
# note_on channel=0 note=70 velocity=49 time=0
# note_on channel=0 note=75 velocity=0 time=360
# note_on channel=0 note=73 velocity=59 time=0
# note_on channel=0 note=73 velocity=0 time=120
# note_on channel=0 note=70 velocity=0 time=0
# note_on channel=0 note=63 velocity=0 time=0
# note_on channel=0 note=68 velocity=37 time=0
# note_on channel=0 note=72 velocity=50 time=0
# note_on channel=0 note=63 velocity=37 time=0
# note_on channel=0 note=63 velocity=0 time=960
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=68 velocity=0 time=0
# note_on channel=0 note=75 velocity=56 time=0
# note_on channel=0 note=75 velocity=0 time=475
# note_on channel=0 note=75 velocity=34 time=5
# note_on channel=0 note=72 velocity=34 time=0
# note_on channel=0 note=80 velocity=54 time=0
# note_on channel=0 note=80 velocity=0 time=475
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=75 velocity=34 time=5
# note_on channel=0 note=72 velocity=34 time=0
# note_on channel=0 note=80 velocity=57 time=0
# note_on channel=0 note=80 velocity=0 time=720
# note_on channel=0 note=82 velocity=50 time=0
# note_on channel=0 note=82 velocity=0 time=240
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=73 velocity=34 time=0
# note_on channel=0 note=80 velocity=57 time=0
# note_on channel=0 note=75 velocity=34 time=0
# note_on channel=0 note=75 velocity=0 time=475
# note_on channel=0 note=80 velocity=0 time=0
# note_on channel=0 note=73 velocity=0 time=0
# note_on channel=0 note=79 velocity=57 time=5
# note_on channel=0 note=75 velocity=34 time=0
# note_on channel=0 note=73 velocity=34 time=0
# note_on channel=0 note=79 velocity=0 time=720
# note_on channel=0 note=82 velocity=57 time=0
# note_on channel=0 note=82 velocity=0 time=240
# note_on channel=0 note=73 velocity=0 time=0
# note_on channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=82 velocity=57 time=0
# note_on channel=0 note=82 velocity=0 time=475
# note_on channel=0 note=80 velocity=59 time=5
# note_on channel=0 note=75 velocity=35 time=0
# note_on channel=0 note=75 velocity=0 time=475
# note_on channel=0 note=80 velocity=0 time=0
# note_on channel=0 note=73 velocity=37 time=5
# note_on channel=0 note=82 velocity=62 time=0
# note_on channel=0 note=75 velocity=37 time=0
# note_on channel=0 note=75 velocity=0 time=475
# note_on channel=0 note=82 velocity=0 time=0
# note_on channel=0 note=73 velocity=0 time=0
# note_on channel=0 note=75 velocity=40 time=5
# note_on channel=0 note=72 velocity=40 time=0
# note_on channel=0 note=84 velocity=66 time=0
# note_on channel=0 note=84 velocity=0 time=960
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=75 velocity=65 time=0
# note_on channel=0 note=75 velocity=0 time=475
# note_on channel=0 note=84 velocity=73 time=5
# note_on channel=0 note=75 velocity=44 time=0
# note_on channel=0 note=72 velocity=44 time=0
# note_on channel=0 note=72 velocity=0 time=475
# note_on channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=84 velocity=0 time=0
# note_on channel=0 note=75 velocity=44 time=5
# note_on channel=0 note=72 velocity=44 time=0
# note_on channel=0 note=84 velocity=74 time=0
# note_on channel=0 note=84 velocity=0 time=720
# note_on channel=0 note=85 velocity=67 time=0
# note_on channel=0 note=85 velocity=0 time=240
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=75 velocity=0 time=0
# note_on channel=0 note=72 velocity=37 time=0
# note_on channel=0 note=84 velocity=58 time=0
# note_on channel=0 note=76 velocity=37 time=0
# note_on channel=0 note=76 velocity=0 time=475
# note_on channel=0 note=84 velocity=0 time=0
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=76 velocity=36 time=5
# note_on channel=0 note=72 velocity=36 time=0
# note_on channel=0 note=82 velocity=52 time=0
# note_on channel=0 note=82 velocity=0 time=720
# note_on channel=0 note=84 velocity=54 time=0
# note_on channel=0 note=84 velocity=0 time=240
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=76 velocity=0 time=0
# note_on channel=0 note=72 velocity=36 time=0
# note_on channel=0 note=82 velocity=49 time=0
# note_on channel=0 note=77 velocity=36 time=0
# note_on channel=0 note=77 velocity=0 time=475
# note_on channel=0 note=82 velocity=0 time=0
# note_on channel=0 note=72 velocity=0 time=0
# note_on channel=0 note=80 velocity=47 time=5
# note_on channel=0 note=72 velocity=34 time=0
# note_on channel=0 note=77 velocity=34 time=0
# note_on channel=0 note=80 velocity=0 time=160
# note_on channel=0 note=82 velocity=52 time=0
# note_on channel=0 note=82 velocity=0 time=80
# note_on channel=0 note=80 velocity=52 time=0
# note_on channel=0 note=80 velocity=0 time=80
# note_on channel=0 note=79 velocity=52 time=0
# note_on channel=0 note=79 velocity=0 time=80
# ...
# control_change channel=0 control=64 value=0 time=383
# control_change channel=0 control=64 value=127 time=74
# control_change channel=0 control=64 value=0 time=8560
# control_change channel=0 control=64 value=127 time=115
# control_change channel=0 control=64 value=0 time=1325
# control_change channel=0 control=64 value=127 time=52
# control_change channel=0 control=64 value=0 time=1388
# control_change channel=0 control=64 value=127 time=99
# control_change channel=0 control=64 value=0 time=1347
# control_change channel=0 control=64 value=127 time=121
# control_change channel=0 control=64 value=0 time=1320
# control_change channel=0 control=64 value=127 time=134
# control_change channel=0 control=64 value=0 time=1314
# control_change channel=0 control=64 value=127 time=119
# control_change channel=0 control=64 value=0 time=1310
# control_change channel=0 control=64 value=127 time=97
# control_change channel=0 control=64 value=0 time=393
# control_change channel=0 control=64 value=127 time=73
# control_change channel=0 control=64 value=0 time=406
# control_change channel=0 control=64 value=127 time=69
# control_change channel=0 control=64 value=0 time=405
# control_change channel=0 control=64 value=127 time=113
# control_change channel=0 control=64 value=0 time=374
# control_change channel=0 control=64 value=127 time=99
# control_change channel=0 control=64 value=0 time=380
# control_change channel=0 control=64 value=127 time=100
# control_change channel=0 control=64 value=0 time=371
# control_change channel=0 control=64 value=127 time=116
# control_change channel=0 control=64 value=0 time=1332
# control_change channel=0 control=64 value=127 time=73
# control_change channel=0 control=64 value=0 time=1358
# control_change channel=0 control=64 value=127 time=84
# control_change channel=0 control=64 value=0 time=406
# control_change channel=0 control=64 value=127 time=83
# control_change channel=0 control=64 value=0 time=397
# control_change channel=0 control=64 value=127 time=74
# control_change channel=0 control=64 value=0 time=398
# control_change channel=0 control=64 value=127 time=108
# control_change channel=0 control=64 value=0 time=381
# control_change channel=0 control=64 value=127 time=92
# control_change channel=0 control=64 value=0 time=388
# control_change channel=0 control=64 value=127 time=64
# control_change channel=0 control=64 value=0 time=405
# control_change channel=0 control=64 value=127 time=82
# control_change channel=0 control=64 value=0 time=408
# control_change channel=0 control=64 value=127 time=93
# control_change channel=0 control=64 value=0 time=390
# control_change channel=0 control=64 value=127 time=111
# control_change channel=0 control=64 value=0 time=367
# control_change channel=0 control=64 value=127 time=85
# control_change channel=0 control=64 value=0 time=395
# control_change channel=0 control=64 value=127 time=92
# control_change channel=0 control=64 value=0 time=389
# control_change channel=0 control=64 value=127 time=84
# control_change channel=0 control=64 value=0 time=388
# control_change channel=0 control=64 value=127 time=120
# control_change channel=0 control=64 value=0 time=368
# control_change channel=0 control=64 value=127 time=91
# control_change channel=0 control=64 value=0 time=390
# control_change channel=0 control=64 value=127 time=90
# control_change channel=0 control=64 value=0 time=378
# control_change channel=0 control=64 value=127 time=130
# control_change channel=0 control=64 value=0 time=1306
# control_change channel=0 control=64 value=127 time=109
# control_change channel=0 control=64 value=0 time=1331
# control_change channel=0 control=64 value=127 time=109
# control_change channel=0 control=64 value=0 time=1337
# control_change channel=0 control=64 value=127 time=100
# control_change channel=0 control=64 value=0 time=386
# control_change channel=0 control=64 value=127 time=94
# control_change channel=0 control=64 value=0 time=387
# control_change channel=0 control=64 value=127 time=93
# control_change channel=0 control=64 value=0 time=374
# control_change channel=0 control=64 value=127 time=75
# control_change channel=0 control=64 value=0 time=418
# control_change channel=0 control=64 value=127 time=73
# control_change channel=0 control=64 value=0 time=407
# control_change channel=0 control=64 value=127 time=96
# control_change channel=0 control=64 value=0 time=380
# control_change channel=0 control=64 value=127 time=88
# control_change channel=0 control=64 value=0 time=1351
# control_change channel=0 control=64 value=127 time=78
# control_change channel=0 control=64 value=0 time=1366
# control_change channel=0 control=64 value=127 time=101
# control_change channel=0 control=64 value=0 time=379
# control_change channel=0 control=64 value=127 time=94
# control_change channel=0 control=64 value=0 time=386
# control_change channel=0 control=64 value=127 time=80
# control_change channel=0 control=64 value=0 time=391
# control_change channel=0 control=64 value=127 time=106
# control_change channel=0 control=64 value=0 time=384
# control_change channel=0 control=64 value=127 time=90
# control_change channel=0 control=64 value=0 time=390
# control_change channel=0 control=64 value=127 time=84
# control_change channel=0 control=64 value=0 time=390
# control_change channel=0 control=64 value=127 time=90
# control_change channel=0 control=64 value=0 time=396
# control_change channel=0 control=64 value=127 time=90
# control_change channel=0 control=64 value=0 time=390
# control_change channel=0 control=64 value=127 time=96
# control_change channel=0 control=64 value=0 time=474
# control_change channel=0 control=64 value=127 time=86
# control_change channel=0 control=64 value=0 time=301
# control_change channel=0 control=64 value=127 time=87
# control_change channel=0 control=64 value=0 time=397
# control_change channel=0 control=64 value=127 time=89
# control_change channel=0 control=64 value=0 time=383
# control_change channel=0 control=64 value=127 time=74
# control_change channel=0 control=64 value=0 time=8560
# control_change channel=0 control=64 value=127 time=115
# control_change channel=0 control=64 value=0 time=1325
# control_change channel=0 control=64 value=127 time=52
# control_change channel=0 control=64 value=0 time=1388
# control_change channel=0 control=64 value=127 time=99
# control_change channel=0 control=64 value=0 time=1347
# control_change channel=0 control=64 value=127 time=121
# control_change channel=0 control=64 value=0 time=1320
# control_change channel=0 control=64 value=127 time=134
# control_change channel=0 control=64 value=0 time=1314
# control_change channel=0 control=64 value=127 time=119
# control_change channel=0 control=64 value=0 time=1310
# control_change channel=0 control=64 value=127 time=97
# control_change channel=0 control=64 value=0 time=393
# control_change channel=0 control=64 value=127 time=73
# control_change channel=0 control=64 value=0 time=406
# control_change channel=0 control=64 value=127 time=69
# control_change channel=0 control=64 value=0 time=405
# control_change channel=0 control=64 value=127 time=113
# control_change channel=0 control=64 value=0 time=374
# control_change channel=0 control=64 value=127 time=99
# control_change channel=0 control=64 value=0 time=380
# control_change channel=0 control=64 value=127 time=100
# control_change channel=0 control=64 value=0 time=371
# control_change channel=0 control=64 value=127 time=116
# control_change channel=0 control=64 value=0 time=1332
# control_change channel=0 control=64 value=127 time=73
# control_change channel=0 control=64 value=0 time=1358
# control_change channel=0 control=64 value=127 time=84
# control_change channel=0 control=64 value=0 time=406
# control_change channel=0 control=64 value=127 time=83
# control_change channel=0 control=64 value=0 time=397
# control_change channel=0 control=64 value=127 time=74
# control_change channel=0 control=64 value=0 time=398
# control_change channel=0 control=64 value=127 time=108
# control_change channel=0 control=64 value=0 time=381
# control_change channel=0 control=64 value=127 time=92
# control_change channel=0 control=64 value=0 time=388
# control_change channel=0 control=64 value=127 time=64
# control_change channel=0 control=64 value=0 time=405
# control_change channel=0 control=64 value=127 time=82
# control_change channel=0 control=64 value=0 time=408
# control_change channel=0 control=64 value=127 time=93
# control_change channel=0 control=64 value=0 time=390
# control_change channel=0 control=64 value=127 time=111
# control_change channel=0 control=64 value=0 time=367
# control_change channel=0 control=64 value=127 time=85
# control_change channel=0 control=64 value=0 time=395
# control_change channel=0 control=64 value=127 time=92
# control_change channel=0 control=64 value=0 time=389
# control_change channel=0 control=64 value=127 time=84
# control_change channel=0 control=64 value=0 time=388
# control_change channel=0 control=64 value=127 time=120
# control_change channel=0 control=64 value=0 time=368
# control_change channel=0 control=64 value=127 time=91
# control_change channel=0 control=64 value=0 time=390
# control_change channel=0 control=64 value=127 time=90
# control_change channel=0 control=64 value=0 time=378
# control_change channel=0 control=64 value=127 time=130
# control_change channel=0 control=64 value=0 time=1311
# control_change channel=0 control=64 value=127 time=175
# control_change channel=0 control=64 value=0 time=2707
# control_change channel=0 control=64 value=127 time=53
# control_change channel=0 control=64 value=0 time=1389
# control_change channel=0 control=64 value=127 time=111
# control_change channel=0 control=64 value=0 time=1325
# control_change channel=0 control=64 value=127 time=115
# control_change channel=0 control=64 value=0 time=5160
# control_change channel=0 control=64 value=127 time=180
# control_change channel=0 control=64 value=0 time=1750
# control_change channel=0 control=64 value=127 time=230
# control_change channel=0 control=64 value=0 time=252
# control_change channel=0 control=64 value=127 time=200
# control_change channel=0 control=64 value=0 time=758
# control_change channel=0 control=64 value=127 time=369
# control_change channel=0 control=64 value=0 time=1067
# control_change channel=0 control=64 value=127 time=368
# control_change channel=0 control=64 value=0 time=1077
# control_change channel=0 control=64 value=127 time=179
# control_change channel=0 control=64 value=0 time=1257
# control_change channel=0 control=64 value=127 time=233
# control_change channel=0 control=64 value=0 time=253
# control_change channel=0 control=64 value=127 time=199
# control_change channel=0 control=64 value=0 time=756
# control_change channel=0 control=64 value=127 time=155
# control_change channel=0 control=64 value=0 time=329
# control_change channel=0 control=64 value=127 time=129
# control_change channel=0 control=64 value=0 time=351
# control_change channel=0 control=64 value=127 time=136
# control_change channel=0 control=64 value=0 time=342
# control_change channel=0 control=64 value=127 time=524
# control_change channel=0 control=64 value=0 time=913
# control_change channel=0 control=64 value=127 time=219
# control_change channel=0 control=64 value=0 time=1221
# control_change channel=0 control=64 value=127 time=276
# control_change channel=0 control=64 value=0 time=208
# control_change channel=0 control=64 value=127 time=173
# control_change channel=0 control=64 value=0 time=776
# control_change channel=0 control=64 value=127 time=379
# control_change channel=0 control=64 value=0 time=1068
# control_change channel=0 control=64 value=127 time=367
# control_change channel=0 control=64 value=0 time=1074
# control_change channel=0 control=64 value=127 time=232
# control_change channel=0 control=64 value=0 time=1206
# control_change channel=0 control=64 value=127 time=220
# control_change channel=0 control=64 value=0 time=1228
# control_change channel=0 control=64 value=127 time=53
# control_change channel=0 control=64 value=0 time=425
# control_change channel=0 control=64 value=127 time=59
# control_change channel=0 control=64 value=0 time=421
# control_change channel=0 control=64 value=127 time=55
# control_change channel=0 control=64 value=0 time=423
# control_change channel=0 control=64 value=127 time=177
# control_change channel=0 control=64 value=0 time=879
# control_change channel=0 control=64 value=127 time=154
# control_change channel=0 control=64 value=0 time=3100
# control_change channel=0 control=64 value=127 time=2598
# control_change channel=0 control=64 value=0 time=3162
# control_change channel=0 control=64 value=127 time=2631
# control_change channel=0 control=64 value=0 time=1689
# control_change channel=0 control=64 value=127 time=1223
# control_change channel=0 control=64 value=0 time=1657
# control_change channel=0 control=64 value=127 time=1574
# control_change channel=0 control=64 value=0 time=1316
# control_change channel=0 control=64 value=127 time=310
# control_change channel=0 control=64 value=0 time=1120
# control_change channel=0 control=64 value=127 time=212
# control_change channel=0 control=64 value=0 time=1238
# control_change channel=0 control=64 value=127 time=216
# control_change channel=0 control=64 value=0 time=264
# control_change channel=0 control=64 value=127 time=216
# control_change channel=0 control=64 value=0 time=739
# control_change channel=0 control=64 value=127 time=324
# control_change channel=0 control=64 value=0 time=1111
# control_change channel=0 control=64 value=127 time=374
# control_change channel=0 control=64 value=0 time=1066
# control_change channel=0 control=64 value=127 time=268
# control_change channel=0 control=64 value=0 time=1182
# control_change channel=0 control=64 value=127 time=196
# control_change channel=0 control=64 value=0 time=286
# control_change channel=0 control=64 value=127 time=171
# control_change channel=0 control=64 value=0 time=542
# control_change channel=0 control=64 value=0 time=3119
# control_change channel=0 control=64 value=127 time=208
# control_change channel=0 control=64 value=0 time=1237
# control_change channel=0 control=64 value=127 time=231
# control_change channel=0 control=64 value=0 time=253
# control_change channel=0 control=64 value=127 time=227
# control_change channel=0 control=64 value=0 time=729
# control_change channel=0 control=64 value=127 time=320
# control_change channel=0 control=64 value=0 time=1118
# control_change channel=0 control=64 value=127 time=313
# control_change channel=0 control=64 value=0 time=1120
# control_change channel=0 control=64 value=127 time=268
# control_change channel=0 control=64 value=0 time=1182
# control_change channel=0 control=64 value=127 time=196
# control_change channel=0 control=64 value=0 time=286
# control_change channel=0 control=64 value=127 time=171
# control_change channel=0 control=64 value=0 time=777
# control_change channel=0 control=64 value=127 time=1532
# control_change channel=0 control=64 value=0 time=868
# control_change channel=0 control=64 value=127 time=2046
# control_change channel=0 control=64 value=0 time=1079
# control_change channel=0 control=64 value=127 time=281
# control_change channel=0 control=64 value=0 time=446
# control_change channel=0 control=64 value=127 time=217
# control_change channel=0 control=64 value=0 time=263
# control_change channel=0 control=64 value=127 time=194
# control_change channel=0 control=64 value=0 time=282
# control_change channel=0 control=64 value=127 time=339
# control_change channel=0 control=64 value=0 time=1973
# <meta message end_of_track time=0>
# <meta message track_name name='Schubert: Impromptu D 935 No. 2' time=0>
# <meta message end_of_track time=0>
# <meta message track_name name='Copyright © 2007 by Bernd Krueger' time=0>
# <meta message end_of_track time=0>
# <meta message track_name name='http://www.piano-midi.de' time=0>
# <meta message end_of_track time=0>
# <meta message track_name name='Edition: 2014-03-20' time=0>
# <meta message end_of_track time=0>
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-69-1777af96c2b2> in <module>()
# ----> 1 getFeat(rawData[0])
#
# <ipython-input-68-2b63f0aac10b> in getFeat(mid)
#      11 #                 return str(msg.numerator) + ',' + str(msg.denominator)
#      12
# ---> 13     raise(NotImplementedError)
#
# NotImplementedError:
